# %% [markdown]
# <a href="https://colab.research.google.com/github/antonum/Timescale-Workshops/blob/main/RAG_in_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG in a single SQL statement
#
# ![Timescale logo](https://docs.timescale.com/static/logo-white-c6cf9b4c58cd066908a6335ece1957fd.svg)

# %%
import psycopg2
from google.colab import userdata
#CONNECTION="postgres://tsdbadmin:xxxxxxx.yyyyy.tsdb.cloud.timescale.com:39966/tsdb?sslmode=require"
CONNECTION=userdata.get('TS_CONNECTION')
conn = psycopg2.connect(CONNECTION)
cursor = conn.cursor()

# %%
import pandas as pd
# helper function to convert SQL Results to the dataframe
def sql_results_to_df(cursor):
  columns = [desc[0] for desc in cursor.description]
  data = cursor.fetchall()
  df = pd.DataFrame(data, columns=columns)
  return df

# %%
query = """
DROP TABLE IF EXISTS wiki_movie_plots_with_summaries CASCADE;
"""
cursor.execute(query)
conn.commit()

# %%
query = """
select ai.load_dataset('vishnupriyavr/wiki-movie-plots-with-summaries', if_table_exists=>'drop' );
"""
cursor.execute(query)
conn.commit()

# %%
query = """
select "Release Year", "Title", "Plot" from "wiki_movie_plots_with_summaries"
ORDER BY "Release Year" DESC
LIMIT 10;
"""
cursor.execute(query)
sql_results_to_df(cursor)
# Out:
#    Release Year                            Title  \
# 0          2017                 The Book of Love
# 1          2017  The Resurrection of Gavin Stone
# 2          2017                  The Bye Bye Man
# 3          2017                      100 Streets
# 4          2017                            Split
# 5          2017       xXx: Return of Xander Cage
# 6          2017           Underworld: Blood Wars
# 7          2017                   Monster Trucks
# 8          2017                        Sleepless
# 9          2017              Trespass Against Us
#
#                                                 Plot
# 0  After the accidental death of his free-spirite...
# 1  Former child star Gavin Stone is now a washed-...
# 2  In 1969, a mass murder occurs in which a man k...
# 3  The film centers on three characters who have ...
# 4  Casey Cooke is an emotionally withdrawn teenag...
# 5  NSA Agent Augustus Gibbons attempts to recruit...
# 6  The remaining vampire covens are on the verge ...
# 7  Terravex Oil is in the midst of a fracking ope...
# 8  In Las Vegas, vice LVMPD policemen Vincent Dow...
# 9  To give a better future to his son, Chad Cutle...

# %%
conn.commit()
query = """
ALTER TABLE wiki_movie_plots_with_summaries
ADD COLUMN id SERIAL PRIMARY KEY;
"""
cursor.execute(query)
conn.commit()

# %%
conn.commit()

# %%
# create vectorizer
query = """
SELECT ai.create_vectorizer(
   'wiki_movie_plots_with_summaries'::regclass,
   destination => 'movies_embeddings3',
   embedding => ai.embedding_openai('text-embedding-3-small', 1536),
   chunking => ai.chunking_recursive_character_text_splitter('Plot'),
   indexing => ai.indexing_diskann()
);
"""
cursor.execute(query)
sql_results_to_df(cursor)
conn.commit()

# %%
query = """
select * from movies_embeddings3
limit 10;
"""
cursor.execute(query)
sql_results_to_df(cursor)
# Out:
#                          embedding_uuid  chunk_seq  \
# 0  4afe84a3-1b94-453b-9b01-e33dce512dd2          0
# 1  78b2c385-daba-458f-bdef-2f649aab844b          0
# 2  3a43d48f-4ffe-487b-973f-07a507043996          0
# 3  e56cc832-88ba-414e-85e4-00d9f363d312          0
# 4  9b77c8b5-5d1d-49a2-8166-4845caf0e361          1
# 5  ff0e853c-039d-43b2-9f80-4786a066707f          0
# 6  ec5f58fa-7285-4b7f-b7b7-26482f8f2aef          0
# 7  39cdd043-b0e5-4961-b3d6-6dd4696caf92          1
# 8  a85686af-ac89-4177-9111-12fcd7a05acc          0
# 9  989a8d3a-8c2e-4b38-821c-7dc59adfd66f          0
#
#                                                chunk  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  . "Teddy" aims his rifle upward at the tree an...
# 5  The earliest known adaptation of the classic f...
# 6  Alice follows a large white rabbit down a "Rab...
# 7  She enters a kitchen, in which there is a cook...
# 8  Described as "a liberal adaptation of Mrs. She...
# 9  In this film's version of the story, four of t...
#
#                                            embedding  Release Year  \
# 0  [-0.011869899,0.039477732,-0.002416647,0.02663...          1901
# 1  [0.008271699,-0.009916825,-0.013569008,-0.0024...          1901
# 2  [-0.01929859,0.007857089,0.0142286215,0.005434...          1901
# 3  [-0.007654703,-0.0008206655,-0.008439056,-0.01...          1901
# 4  [0.039645053,0.007756961,-0.0022020945,-0.0145...          1901
# 5  [0.0042759217,0.0065219556,0.0072925612,-0.020...          1902
# 6  [0.0014899907,-0.034087874,0.046704993,-0.0035...          1903
# 7  [0.008044878,-0.029636292,0.022837073,0.014130...          1903
# 8  [0.015609496,0.03383736,-0.068681784,0.0091894...          1910
# 9  [-0.020853277,0.053743005,-0.042499077,-0.0053...          1955
#
#                               Title Origin/Ethnicity  \
# 0            Kansas Saloon Smashers         American
# 1     Love by the Light of the Moon         American
# 2           The Martyred Presidents         American
# 3  Terrible Teddy, the Grizzly King         American
# 4  Terrible Teddy, the Grizzly King         American
# 5            Jack and the Beanstalk         American
# 6               Alice in Wonderland         American
# 7               Alice in Wonderland         American
# 8                      Frankenstein         American
# 9                      Rage at Dawn         American
#
#                              Director  \
# 0                             Unknown
# 1                             Unknown
# 2                             Unknown
# 3                             Unknown
# 4                             Unknown
# 5  George S. Fleming, Edwin S. Porter
# 6                      Cecil Hepworth
# 7                      Cecil Hepworth
# 8                    J. Searle Dawley
# 9                          Tim Whelan
#
#                                                 Cast    Genre  \
# 0                                               None  unknown
# 1                                               None  unknown
# 2                                               None  unknown
# 3                                               None  unknown
# 4                                               None  unknown
# 5                                               None  unknown
# 6                                          May Clark  unknown
# 7                                          May Clark  unknown
# 8  Augustus Phillips, Charles Stanton Ogle, Mary ...  unknown
# 9                     Randolph Scott, Forrest Tucker  western
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 5  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# 6  https://en.wikipedia.org/wiki/Alice_in_Wonderl...
# 7  https://en.wikipedia.org/wiki/Alice_in_Wonderl...
# 8  https://en.wikipedia.org/wiki/Frankenstein_(19...
# 9         https://en.wikipedia.org/wiki/Rage_at_Dawn
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  Lasting just 61 seconds and consisting of two ...
# 5  The earliest known adaptation of the classic f...
# 6  Alice follows a large white rabbit down a "Rab...
# 7  Alice follows a large white rabbit down a "Rab...
# 8  Described as "a liberal adaptation of Mrs. She...
# 9  In this film's version of the story, four of t...
#
#                                          PlotSummary  id
# 0  Carrie Nation and her followers burst into a s...   1
# 1  The moon, painted with a smiling face hangs ov...   2
# 2  The film, just over a minute long, is composed...   3
# 3  The first shot is set in a wood during winter ...   4
# 4  The first shot is set in a wood during winter ...   4
# 5  The earliest known adaptation of the classic f...   5
# 6  Alice follows a large white rabbit down a "Rab...   6
# 7  Alice follows a large white rabbit down a "Rab...   6
# 8  The plot description in the Edison Kinetogram ...   7
# 9  In this film's version of the story, four of t...   8

# %%
query = """
--Generate single embedding
SELECT ai.openai_embed('text-embedding-3-small', 'good food', dimensions=>1536);
"""
cursor.execute(query)
sql_results_to_df(cursor)
# Out:
#                                         openai_embed
# 0  [-0.012252327,-0.014671666,-0.027942661,-0.012...

# %%
query = """
SELECT
"Release Year", "Title", "Plot",
    embedding <=> ai.openai_embed(
        'text-embedding-3-small',
        'James Bond in Rome, Italy', -- your RAG query
        dimensions => 1536
    ) AS vector_distance
FROM
    movies_embeddings3
ORDER BY
    vector_distance
LIMIT 10;
"""
cursor.execute(query)
sql_results_to_df(cursor)
# Out:
#    Release Year                            Title  \
# 0          2008                Quantum of Solace
# 1          2008                Quantum of Solace
# 2          1963            From Russia with Love
# 3          1963            From Russia with Love
# 4          1963            From Russia with Love
# 5          1969  On Her Majesty's Secret Service
# 6          2008                Quantum of Solace
# 7          2008                Quantum of Solace
# 8          2015                          Spectre
# 9          2008                Quantum of Solace
#
#                                                 Plot  vector_distance
# 0  James Bond is driving from Lake Garda to Siena...         0.403066
# 1  James Bond is driving from Lake Garda to Siena...         0.403066
# 2  Seeking to exact revenge on James Bond (007) f...         0.418277
# 3  Seeking to exact revenge on James Bond (007) f...         0.418851
# 4  Seeking to exact revenge on James Bond (007) f...         0.424854
# 5  In Portugal, James Bond – agent 007, sometimes...         0.428215
# 6  James Bond is driving from Lake Garda to Siena...         0.432349
# 7  James Bond is driving from Lake Garda to Siena...         0.432349
# 8  A posthumous message from the previous M leads...         0.437267
# 9  James Bond is driving from Lake Garda to Siena...         0.437724

# %%
query = """
-- Ask a question to OpenAI using pgAI
SELECT ai.openai_chat_complete(
  'gpt-4o',
  jsonb_build_array(
    jsonb_build_object(
      'role', 'system',
      'content', 'You are a helpful assistant.'
    ),
    jsonb_build_object(
      'role', 'user',
      'content', 'What famous movies are set in Rome?'
    )
  )
)->'choices'->0->'message'->>'content';
"""
cursor.execute(query)
sql_results_to_df(cursor)
# Out:
#                                             ?column?
# 0  Rome has been the backdrop for many famous mov...

# %% [markdown]
# # RAG In a single SQL Query
#
# Combining semantic search with call to generative AI model gives us full RAG solution in a single SQL query

# %%
query = """
-- Summarization of vector query results
SELECT
    ai.openai_chat_complete(
        'gpt-4o',
        jsonb_build_array(
            jsonb_build_object(
                'role', 'system',
                'content', 'you are a helpful assistant'
            ),
            jsonb_build_object(
                'role', 'user',
                'content', concat(E'Recommend the movie for James Bond in Rome, Italy. Use only the context below context: ',string_agg(x.report, E'\n\n'))
            )
        )
    )->'choices'->0->'message'->>'content' AS summary,
    string_agg(x.report, E'\n\n') AS raw_descriptions
FROM (
    SELECT
        id,
        ' Title: ' || "Title" ||' Year: ' || "Release Year" ||  ' Plot: ' || Chunk AS report,
        embedding <=> ai.openai_embed(
            'text-embedding-3-small',
            'James Bond in Rome, Italy', -- your semantic query
            dimensions => 1536
        ) AS distance
    FROM
        movies_embeddings3
    -- WHERE station_name LIKE '%Bay%'
    ORDER BY
        distance
    LIMIT 10
) x;

"""
cursor.execute(query)
sql_results_to_df(cursor)
# Out:
#                                              summary  \
# 0  I recommend the movie **"Spectre" (2015)** for...
#
#                                     raw_descriptions
# 0   Title: Quantum of Solace Year: 2008 Plot: Jam...
